# %%
import numpy as np
import pandas as pd
import openmdao.api as om
import aviary
import aviary.api as av
import aviary.subsystems as avs
from openmdao.utils.options_dictionary import OptionsDictionary
from aviary.variable_info.variables import Aircraft
from standard_evaluator import get_interface, show_structure, create_problem, get_state, set_state, load_state, save_state
from standard_evaluator import save_assembly, load_assembly


from aviary.subsystems.geometry.flops_based.prep_geom import PrepGeom
# Out:
# matlabengine not available.

# %%
# Create an empty group
model = om.Group()

prep = PrepGeom()
model.add_subsystem('prep_geom', prep, promotes=['*'])

prob = om.Problem(model)

prob.setup()

# Load values for all variables from a csv file, and then set them
new_df = pd.read_csv('input.csv')
# Drop the unused column
new_df = new_df.drop(["Unnamed: 0"], axis=1)
for (name, val) in (new_df.iloc[0]).items():
    prob.set_val(name, val=np.array(	[val]	))

help_dict = {Aircraft.Propulsion.TOTAL_NUM_FUSELAGE_ENGINES: 1}
prob.model._subsystems_myproc[1]._subsystems_myproc[4].options.set(**help_dict)
help_dict = {Aircraft.Engine.NUM_ENGINES: np.array([2])}
prob.model._subsystems_myproc[1]._subsystems_myproc[6].options.set(**help_dict)
prob.model._subsystems_myproc[1]._subsystems_myproc[8].options.set(**help_dict)

# Run the model
prob.run_model()
_ = prob.model.list_inputs(shape=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5 model.add_subsystem('prep_geom', prep, promotes=['*'])
#       6
#       7 prob = om.Problem(model)
#       8
# ----> 9 prob.setup()
#      10
#      11 # Load values for all variables from a csv file, and then set them
#      12 new_df = pd.read_csv('input.csv')
#
# File c:\dev\standard-evaluator\.venv\Lib\site-packages\openmdao\core\problem.py:1142, in Problem.setup(self, check, logger, mode, force_alloc_complex, distributed_vector_class, local_vector_class, derivatives, parent)
#    1139 self._metadata['reports_dir'] = self.get_reports_dir()
#    1141 try:
# -> 1142     model._setup(model_comm, self._metadata)
#    1143 finally:
#    1144     # whenever we're outside of model._setup, static mode should be True so that anything
#    1145     # added outside of _setup will persist.
#    1146     self._metadata['static_mode'] = True
#
# File c:\dev\standard-evaluator\.venv\Lib\site-packages\openmdao\core\group.py:775, in Group._setup(self, comm, prob_meta)
#     772 self._post_components = None
#     774 # Besides setting up the processors, this method also builds the model hierarchy.
# --> 775 self._setup_procs(self.pathname, comm, prob_meta)
#     777 prob_meta['config_info'] = _ConfigInfo()
#     779 try:
#     780     # Recurse model from the bottom to the top for configuring.
#
# File c:\dev\standard-evaluator\.venv\Lib\site-packages\openmdao\core\group.py:646, in Group._setup_procs(self, pathname, comm, prob_meta)
#     644 # Perform recursion
#     645 for subsys in self._sorted_subsystems_myproc:
# --> 646     subsys._setup_procs(subsys.pathname, sub_comm, prob_meta)
#     648 # build a list of local subgroups to speed up later loops
#     649 self._subgroups_myproc = [s for s in self._subsystems_myproc if isinstance(s, Group)]
#
# File c:\dev\standard-evaluator\.venv\Lib\site-packages\openmdao\core\group.py:646, in Group._setup_procs(self, pathname, comm, prob_meta)
#     644 # Perform recursion
#     645 for subsys in self._sorted_subsystems_myproc:
# --> 646     subsys._setup_procs(subsys.pathname, sub_comm, prob_meta)
#     648 # build a list of local subgroups to speed up later loops
#     649 self._subgroups_myproc = [s for s in self._subsystems_myproc if isinstance(s, Group)]
#
# File c:\dev\standard-evaluator\.venv\Lib\site-packages\openmdao\core\component.py:237, in Component._setup_procs(self, pathname, comm, prob_meta)
#     234 for io in ['input', 'output']:
#     235     self._var_rel_names[io].extend(self._static_var_rel_names[io])
# --> 237 self.setup()
#     238 self._setup_check()
#     240 self._setup_vector_class()
#
# File c:\dev\standard-evaluator\.venv\Lib\site-packages\aviary\subsystems\geometry\flops_based\landing_gear.py:49, in MainGearLength.setup(self)
#      48 def setup(self):
# ---> 49     num_engine_type = len(self.options[Aircraft.Engine.NUM_ENGINES])
#      50     if isinstance(self.options[Aircraft.Engine.NUM_ENGINES], np.ndarray):
#      51         num_wing_engines_total = sum(self.options[Aircraft.Engine.NUM_WING_ENGINES])
#
# TypeError: object of type 'int' has no len()

# %%
om.n2(prob, 'before.n2.html', display_in_notebook=False,  )
#om.n2(prob, 'before.n2.html', )

# %%
info = get_interface(prob.model)
state = get_state(prob.model, info)


save_assembly(prob, assembly_name='demo_group.json', state_name='state.h5')

# Now loading the structure and state from these files
new_problem = load_assembly(assembly_name='demo_group.json', state_name='state.h5')
_ = new_problem.model.list_inputs(shape=True, units=True)

new_problem.run_model()
# Out:
# ** This is a group, special handling needed for prep_geom in group
# Adding fuselage_prelim component
# Building class fuselage_prelim
# Importing class FuselagePrelim from aviary.subsystems.geometry.flops_based.fuselage
# Adding wing_prelim component
# Building class wing_prelim
# Importing class WingPrelim from aviary.subsystems.geometry.flops_based.wing
# Adding prelim component
# Building class prelim
# Importing class _Prelim from aviary.subsystems.geometry.flops_based.prep_geom
# Adding wing component
# Building class wing
# Importing class _Wing from aviary.subsystems.geometry.flops_based.prep_geom
# Adding tail component
# Building class tail
# Importing class _Tail from aviary.subsystems.geometry.flops_based.prep_geom
# Adding fuselage component
# Building class fuselage
# Importing class _Fuselage from aviary.subsystems.geometry.flops_based.prep_geom
# Adding nacelles component
# Building class nacelles
# Importing class Nacelles from aviary.subsystems.geometry.flops_based.nacelle
# Adding canard component
# Building class canard
# Importing class Canard from aviary.subsystems.geometry.flops_based.canard
# Adding characteristic_lengths component
# Building class characteristic_lengths
# Importing class CharacteristicLengths from aviary.subsystems.geometry.flops_based.characteristic_lengths
# Adding total_wetted_area component
# Building class total_wetted_area
# Importing class TotalWettedArea from aviary.subsystems.geometry.flops_based.wetted_area_total
# 78 Input(s) in 'model'
#
# varname                                              val           units     shape  prom_name
# ---------------------------------------------------  ------------  --------  -----  -----------------------------------------------
# prep_geom
#   fuselage_prelim
#     aircraft:fuselage:length                         [0.]          ft        (1,)   aircraft:fuselage:length
#     aircraft:fuselage:max_height                     [0.]          ft        (1,)   aircraft:fuselage:max_height
#     aircraft:fuselage:max_width                      [0.]          ft        (1,)   aircraft:fuselage:max_width
#   wing_prelim
#     aircraft:wing:area                               [0.]          ft**2     (1,)   aircraft:wing:area
#     aircraft:wing:glove_and_bat                      [0.]          ft**2     (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:span                               [0.]          ft        (1,)   aircraft:wing:span
#   prelim
#     aircraft:fuselage:avg_diameter                   [0.]          ft        (1,)   aircraft:fuselage:avg_diameter
#     aircraft:fuselage:max_width                      [0.]          ft        (1,)   aircraft:fuselage:max_width
#     aircraft:horizontal_tail:area                    [0.]          ft**2     (1,)   aircraft:horizontal_tail:area
#     aircraft:horizontal_tail:aspect_ratio            [0.]          unitless  (1,)   aircraft:horizontal_tail:aspect_ratio
#     aircraft:horizontal_tail:taper_ratio             [0.8]         unitless  (1,)   aircraft:horizontal_tail:taper_ratio
#     aircraft:horizontal_tail:thickness_to_chord      [0.]          unitless  (1,)   aircraft:horizontal_tail:thickness_to_chord
#     aircraft:vertical_tail:area                      [0.]          ft**2     (1,)   aircraft:vertical_tail:area
#     aircraft:vertical_tail:aspect_ratio              [0.]          unitless  (1,)   aircraft:vertical_tail:aspect_ratio
#     aircraft:vertical_tail:taper_ratio               [0.8]         unitless  (1,)   aircraft:vertical_tail:taper_ratio
#     aircraft:vertical_tail:thickness_to_chord        [0.]          unitless  (1,)   aircraft:vertical_tail:thickness_to_chord
#     aircraft:wing:area                               [0.]          ft**2     (1,)   aircraft:wing:area
#     aircraft:wing:glove_and_bat                      [0.]          ft**2     (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:span                               [0.]          ft        (1,)   aircraft:wing:span
#     aircraft:wing:taper_ratio                        [0.]          unitless  (1,)   aircraft:wing:taper_ratio
#     aircraft:wing:thickness_to_chord                 [0.]          unitless  (1,)   aircraft:wing:thickness_to_chord
#   wing
#     prep_geom:_Names:CROOT                           [0.21972222]  unitless  (1,)   wing.prep_geom:_Names:CROOT
#     prep_geom:_Names:CROOTB                          [0.16479167]  unitless  (1,)   wing.prep_geom:_Names:CROOTB
#     prep_geom:_Names:XDX                             [15.]         unitless  (1,)   wing.prep_geom:_Names:XDX
#     prep_geom:_Names:XMULT                           [2.]          unitless  (1,)   wing.prep_geom:_Names:XMULT
#     aircraft:wing:area                               [0.]          ft**2     (1,)   aircraft:wing:area
#     aircraft:wing:wetted_area_scaler                 [1.]          unitless  (1,)   aircraft:wing:wetted_area_scaler
#   tail
#     prep_geom:_Names:XMULTH                          [2.1935]      unitless  (1,)   tail.prep_geom:_Names:XMULTH
#     prep_geom:_Names:XMULTV                          [2.]          unitless  (1,)   tail.prep_geom:_Names:XMULTV
#     aircraft:horizontal_tail:area                    [0.]          ft**2     (1,)   aircraft:horizontal_tail:area
#     aircraft:horizontal_tail:vertical_tail_fraction  [0.]          unitless  (1,)   aircraft:horizontal_tail:vertical_tail_fraction
#     aircraft:horizontal_tail:wetted_area_scaler      [1.]          unitless  (1,)   aircraft:horizontal_tail:wetted_area_scaler
#     aircraft:vertical_tail:area                      [0.]          ft**2     (1,)   aircraft:vertical_tail:area
#     aircraft:vertical_tail:wetted_area_scaler        [1.]          unitless  (1,)   aircraft:vertical_tail:wetted_area_scaler
#   fuselage
#     prep_geom:_Names:CROOTB                          [0.16479167]  unitless  (1,)   fuselage.prep_geom:_Names:CROOTB
#     prep_geom:_Names:CROTVT                          [0.]          unitless  (1,)   fuselage.prep_geom:_Names:CROTVT
#     prep_geom:_Names:CRTHTB                          [4.81919191]  unitless  (1,)   fuselage.prep_geom:_Names:CRTHTB
#     aircraft:fuselage:avg_diameter                   [0.]          ft        (1,)   aircraft:fuselage:avg_diameter
#     aircraft:fuselage:length                         [0.]          ft        (1,)   aircraft:fuselage:length
#     aircraft:fuselage:wetted_area_scaler             [1.]          unitless  (1,)   aircraft:fuselage:wetted_area_scaler
#     aircraft:horizontal_tail:thickness_to_chord      [0.]          unitless  (1,)   aircraft:horizontal_tail:thickness_to_chord
#     aircraft:horizontal_tail:vertical_tail_fraction  [0.]          unitless  (1,)   aircraft:horizontal_tail:vertical_tail_fraction
#     aircraft:vertical_tail:thickness_to_chord        [0.]          unitless  (1,)   aircraft:vertical_tail:thickness_to_chord
#     aircraft:wing:area                               [0.]          ft**2     (1,)   aircraft:wing:area
#     aircraft:wing:aspect_ratio                       [0.]          unitless  (1,)   aircraft:wing:aspect_ratio
#     aircraft:wing:glove_and_bat                      [0.]          ft**2     (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:thickness_to_chord                 [0.]          unitless  (1,)   aircraft:wing:thickness_to_chord
#   nacelles
#     aircraft:nacelle:avg_diameter                    [0.]          ft        (1,)   aircraft:nacelle:avg_diameter
#     aircraft:nacelle:avg_length                      [0.]          ft        (1,)   aircraft:nacelle:avg_length
#     aircraft:nacelle:wetted_area_scaler              [0.]          unitless  (1,)   aircraft:nacelle:wetted_area_scaler
#   canard
#     aircraft:canard:area                             [0.]          ft**2     (1,)   aircraft:canard:area
#     aircraft:canard:thickness_to_chord               [0.]          unitless  (1,)   aircraft:canard:thickness_to_chord
#     aircraft:canard:wetted_area_scaler               [0.8]         unitless  (1,)   aircraft:canard:wetted_area_scaler
#   characteristic_lengths
#     prep_geom:_Names:CROOT                           [0.21972222]  unitless  (1,)   characteristic_lengths.prep_geom:_Names:CROOT
#     aircraft:canard:area                             [0.]          ft**2     (1,)   aircraft:canard:area
#     aircraft:canard:aspect_ratio                     [0.8]         unitless  (1,)   aircraft:canard:aspect_ratio
#     aircraft:canard:thickness_to_chord               [0.]          unitless  (1,)   aircraft:canard:thickness_to_chord
#     aircraft:fuselage:avg_diameter                   [0.]          ft        (1,)   aircraft:fuselage:avg_diameter
#     aircraft:fuselage:length                         [0.]          ft        (1,)   aircraft:fuselage:length
#     aircraft:horizontal_tail:area                    [0.]          ft**2     (1,)   aircraft:horizontal_tail:area
#     aircraft:horizontal_tail:aspect_ratio            [0.]          unitless  (1,)   aircraft:horizontal_tail:aspect_ratio
#     aircraft:horizontal_tail:thickness_to_chord      [0.]          unitless  (1,)   aircraft:horizontal_tail:thickness_to_chord
#     aircraft:nacelle:avg_diameter                    [0.]          ft        (1,)   aircraft:nacelle:avg_diameter
#     aircraft:nacelle:avg_length                      [0.]          ft        (1,)   aircraft:nacelle:avg_length
#     aircraft:vertical_tail:area                      [0.]          ft**2     (1,)   aircraft:vertical_tail:area
#     aircraft:vertical_tail:aspect_ratio              [0.]          unitless  (1,)   aircraft:vertical_tail:aspect_ratio
#     aircraft:vertical_tail:thickness_to_chord        [0.]          unitless  (1,)   aircraft:vertical_tail:thickness_to_chord
#     aircraft:wing:area                               [0.]          ft**2     (1,)   aircraft:wing:area
#     aircraft:wing:aspect_ratio                       [0.]          unitless  (1,)   aircraft:wing:aspect_ratio
#     aircraft:wing:glove_and_bat                      [0.]          ft**2     (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:taper_ratio                        [0.]          unitless  (1,)   aircraft:wing:taper_ratio
#     aircraft:wing:thickness_to_chord                 [0.]          unitless  (1,)   aircraft:wing:thickness_to_chord
#   total_wetted_area
#     aircraft:canard:wetted_area                      [0.]          ft**2     (1,)   aircraft:canard:wetted_area
#     aircraft:fuselage:wetted_area                    [0.]          ft**2     (1,)   aircraft:fuselage:wetted_area
#     aircraft:horizontal_tail:wetted_area             [0.]          ft**2     (1,)   aircraft:horizontal_tail:wetted_area
#     aircraft:nacelle:total_wetted_area               [0.]          ft**2     (1,)   aircraft:nacelle:total_wetted_area
#     aircraft:vertical_tail:wetted_area               [0.]          ft**2     (1,)   aircraft:vertical_tail:wetted_area
#     aircraft:wing:wetted_area                        [0.]          ft**2     (1,)   aircraft:wing:wetted_area

# %%
_ = new_problem.model.list_inputs(shape=True)
# Out:
# 78 Input(s) in 'model'
#
# varname                                              val              shape  prom_name
# ---------------------------------------------------  ---------------  -----  -----------------------------------------------
# prep_geom
#   fuselage_prelim
#     aircraft:fuselage:length                         [120.]           (1,)   aircraft:fuselage:length
#     aircraft:fuselage:max_height                     [0.]             (1,)   aircraft:fuselage:max_height
#     aircraft:fuselage:max_width                      [30.]            (1,)   aircraft:fuselage:max_width
#   wing_prelim
#     aircraft:wing:area                               [2.873]          (1,)   aircraft:wing:area
#     aircraft:wing:glove_and_bat                      [0.5]            (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:span                               [12.]            (1,)   aircraft:wing:span
#   prelim
#     aircraft:fuselage:avg_diameter                   [15.]            (1,)   aircraft:fuselage:avg_diameter
#     aircraft:fuselage:max_width                      [30.]            (1,)   aircraft:fuselage:max_width
#     aircraft:horizontal_tail:area                    [12.]            (1,)   aircraft:horizontal_tail:area
#     aircraft:horizontal_tail:aspect_ratio            [0.8]            (1,)   aircraft:horizontal_tail:aspect_ratio
#     aircraft:horizontal_tail:taper_ratio             [0.8]            (1,)   aircraft:horizontal_tail:taper_ratio
#     aircraft:horizontal_tail:thickness_to_chord      [0.5]            (1,)   aircraft:horizontal_tail:thickness_to_chord
#     aircraft:vertical_tail:area                      [12.]            (1,)   aircraft:vertical_tail:area
#     aircraft:vertical_tail:aspect_ratio              [0.]             (1,)   aircraft:vertical_tail:aspect_ratio
#     aircraft:vertical_tail:taper_ratio               [0.8]            (1,)   aircraft:vertical_tail:taper_ratio
#     aircraft:vertical_tail:thickness_to_chord        [0.]             (1,)   aircraft:vertical_tail:thickness_to_chord
#     aircraft:wing:area                               [2.873]          (1,)   aircraft:wing:area
#     aircraft:wing:glove_and_bat                      [0.5]            (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:span                               [12.]            (1,)   aircraft:wing:span
#     aircraft:wing:taper_ratio                        [0.8]            (1,)   aircraft:wing:taper_ratio
#     aircraft:wing:thickness_to_chord                 [0.]             (1,)   aircraft:wing:thickness_to_chord
#   wing
#     prep_geom:_Names:CROOT                           [0.21972222]     (1,)   wing.prep_geom:_Names:CROOT
#     prep_geom:_Names:CROOTB                          [0.16479167]     (1,)   wing.prep_geom:_Names:CROOTB
#     prep_geom:_Names:XDX                             [15.]            (1,)   wing.prep_geom:_Names:XDX
#     prep_geom:_Names:XMULT                           [2.]             (1,)   wing.prep_geom:_Names:XMULT
#     aircraft:wing:area                               [2.873]          (1,)   aircraft:wing:area
#     aircraft:wing:wetted_area_scaler                 [1.]             (1,)   aircraft:wing:wetted_area_scaler
#   tail
#     prep_geom:_Names:XMULTH                          [2.1935]         (1,)   tail.prep_geom:_Names:XMULTH
#     prep_geom:_Names:XMULTV                          [2.]             (1,)   tail.prep_geom:_Names:XMULTV
#     aircraft:horizontal_tail:area                    [12.]            (1,)   aircraft:horizontal_tail:area
#     aircraft:horizontal_tail:vertical_tail_fraction  [0.]             (1,)   aircraft:horizontal_tail:vertical_tail_fraction
#     aircraft:horizontal_tail:wetted_area_scaler      [1.]             (1,)   aircraft:horizontal_tail:wetted_area_scaler
#     aircraft:vertical_tail:area                      [12.]            (1,)   aircraft:vertical_tail:area
#     aircraft:vertical_tail:wetted_area_scaler        [1.]             (1,)   aircraft:vertical_tail:wetted_area_scaler
#   fuselage
#     prep_geom:_Names:CROOTB                          [0.16479167]     (1,)   fuselage.prep_geom:_Names:CROOTB
#     prep_geom:_Names:CROTVT                          [0.]             (1,)   fuselage.prep_geom:_Names:CROTVT
#     prep_geom:_Names:CRTHTB                          [4.81919191]     (1,)   fuselage.prep_geom:_Names:CRTHTB
#     aircraft:fuselage:avg_diameter                   [15.]            (1,)   aircraft:fuselage:avg_diameter
#     aircraft:fuselage:length                         [120.]           (1,)   aircraft:fuselage:length
#     aircraft:fuselage:wetted_area_scaler             [1.]             (1,)   aircraft:fuselage:wetted_area_scaler
#     aircraft:horizontal_tail:thickness_to_chord      [0.5]            (1,)   aircraft:horizontal_tail:thickness_to_chord
#     aircraft:horizontal_tail:vertical_tail_fraction  [0.]             (1,)   aircraft:horizontal_tail:vertical_tail_fraction
#     aircraft:vertical_tail:thickness_to_chord        [0.]             (1,)   aircraft:vertical_tail:thickness_to_chord
#     aircraft:wing:area                               [2.873]          (1,)   aircraft:wing:area
#     aircraft:wing:aspect_ratio                       [60.68268015]    (1,)   aircraft:wing:aspect_ratio
#     aircraft:wing:glove_and_bat                      [0.5]            (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:thickness_to_chord                 [0.]             (1,)   aircraft:wing:thickness_to_chord
#   nacelles
#     aircraft:nacelle:avg_diameter                    [12.]            (1,)   aircraft:nacelle:avg_diameter
#     aircraft:nacelle:avg_length                      [23.]            (1,)   aircraft:nacelle:avg_length
#     aircraft:nacelle:wetted_area_scaler              [0.]             (1,)   aircraft:nacelle:wetted_area_scaler
#   canard
#     aircraft:canard:area                             [3.]             (1,)   aircraft:canard:area
#     aircraft:canard:thickness_to_chord               [0.3]            (1,)   aircraft:canard:thickness_to_chord
#     aircraft:canard:wetted_area_scaler               [0.8]            (1,)   aircraft:canard:wetted_area_scaler
#   characteristic_lengths
#     prep_geom:_Names:CROOT                           [0.21972222]     (1,)   characteristic_lengths.prep_geom:_Names:CROOT
#     aircraft:canard:area                             [3.]             (1,)   aircraft:canard:area
#     aircraft:canard:aspect_ratio                     [0.8]            (1,)   aircraft:canard:aspect_ratio
#     aircraft:canard:thickness_to_chord               [0.3]            (1,)   aircraft:canard:thickness_to_chord
#     aircraft:fuselage:avg_diameter                   [15.]            (1,)   aircraft:fuselage:avg_diameter
#     aircraft:fuselage:length                         [120.]           (1,)   aircraft:fuselage:length
#     aircraft:horizontal_tail:area                    [12.]            (1,)   aircraft:horizontal_tail:area
#     aircraft:horizontal_tail:aspect_ratio            [0.8]            (1,)   aircraft:horizontal_tail:aspect_ratio
#     aircraft:horizontal_tail:thickness_to_chord      [0.5]            (1,)   aircraft:horizontal_tail:thickness_to_chord
#     aircraft:nacelle:avg_diameter                    [12.]            (1,)   aircraft:nacelle:avg_diameter
#     aircraft:nacelle:avg_length                      [23.]            (1,)   aircraft:nacelle:avg_length
#     aircraft:vertical_tail:area                      [12.]            (1,)   aircraft:vertical_tail:area
#     aircraft:vertical_tail:aspect_ratio              [0.]             (1,)   aircraft:vertical_tail:aspect_ratio
#     aircraft:vertical_tail:thickness_to_chord        [0.]             (1,)   aircraft:vertical_tail:thickness_to_chord
#     aircraft:wing:area                               [2.873]          (1,)   aircraft:wing:area
#     aircraft:wing:aspect_ratio                       [60.68268015]    (1,)   aircraft:wing:aspect_ratio
#     aircraft:wing:glove_and_bat                      [0.5]            (1,)   aircraft:wing:glove_and_bat
#     aircraft:wing:taper_ratio                        [0.8]            (1,)   aircraft:wing:taper_ratio
#     aircraft:wing:thickness_to_chord                 [0.]             (1,)   aircraft:wing:thickness_to_chord
#   total_wetted_area
#     aircraft:canard:wetted_area                      [5.07864]        (1,)   aircraft:canard:wetted_area
#     aircraft:fuselage:wetted_area                    [4437.57742348]  (1,)   aircraft:fuselage:wetted_area
#     aircraft:horizontal_tail:wetted_area             [19.794144]      (1,)   aircraft:horizontal_tail:wetted_area
#     aircraft:nacelle:total_wetted_area               [0.]             (1,)   aircraft:nacelle:total_wetted_area
#     aircraft:vertical_tail:wetted_area               [24.]            (1,)   aircraft:vertical_tail:wetted_area
#     aircraft:wing:wetted_area                        [-0.02170833]    (1,)   aircraft:wing:wetted_area

# %%
_ = new_problem.model.list_outputs(shape=True)
# Out:
# 37 Explicit Output(s) in 'model'
#
# varname                                             val              shape  prom_name
# --------------------------------------------------  ---------------  -----  ----------------------------------------------
# prep_geom
#   fuselage_prelim
#     aircraft:fuselage:avg_diameter                  [15.]            (1,)   aircraft:fuselage:avg_diameter
#     aircraft:fuselage:planform_area                 [3600.]          (1,)   aircraft:fuselage:planform_area
#   wing_prelim
#     aircraft:wing:aspect_ratio                      [60.68268015]    (1,)   aircraft:wing:aspect_ratio
#   prelim
#     prep_geom:_Names:CROOT                          [0.21972222]     (1,)   prelim.prep_geom:_Names:CROOT
#     prep_geom:_Names:CROOTB                         [0.16479167]     (1,)   prelim.prep_geom:_Names:CROOTB
#     prep_geom:_Names:CROTM                          [0.75]           (1,)   prelim.prep_geom:_Names:CROTM
#     prep_geom:_Names:CROTVT                         [0.]             (1,)   prelim.prep_geom:_Names:CROTVT
#     prep_geom:_Names:CRTHTB                         [4.81919191]     (1,)   prelim.prep_geom:_Names:CRTHTB
#     prep_geom:_Names:SPANHT                         [3.09838668]     (1,)   prelim.prep_geom:_Names:SPANHT
#     prep_geom:_Names:SPANVT                         [0.]             (1,)   prelim.prep_geom:_Names:SPANVT
#     prep_geom:_Names:XDX                            [15.]            (1,)   prelim.prep_geom:_Names:XDX
#     prep_geom:_Names:XMULT                          [2.]             (1,)   prelim.prep_geom:_Names:XMULT
#     prep_geom:_Names:XMULTH                         [2.1935]         (1,)   prelim.prep_geom:_Names:XMULTH
#     prep_geom:_Names:XMULTV                         [2.]             (1,)   prelim.prep_geom:_Names:XMULTV
#   wing
#     aircraft:wing:wetted_area                       [-0.02170833]    (1,)   aircraft:wing:wetted_area
#   tail
#     aircraft:horizontal_tail:wetted_area            [19.794144]      (1,)   aircraft:horizontal_tail:wetted_area
#     aircraft:vertical_tail:wetted_area              [24.]            (1,)   aircraft:vertical_tail:wetted_area
#   fuselage
#     aircraft:fuselage:cross_section                 [176.71458676]   (1,)   aircraft:fuselage:cross_section
#     aircraft:fuselage:diameter_to_wing_span         [1.25]           (1,)   aircraft:fuselage:diameter_to_wing_span
#     aircraft:fuselage:length_to_diameter            [8.]             (1,)   aircraft:fuselage:length_to_diameter
#     aircraft:fuselage:wetted_area                   [4437.57742348]  (1,)   aircraft:fuselage:wetted_area
#   nacelles
#     aircraft:nacelle:total_wetted_area              [0.]             (1,)   aircraft:nacelle:total_wetted_area
#     aircraft:nacelle:wetted_area                    [0.]             (1,)   aircraft:nacelle:wetted_area
#   canard
#     aircraft:canard:wetted_area                     [5.07864]        (1,)   aircraft:canard:wetted_area
#   characteristic_lengths
#     aircraft:canard:characteristic_length           [1.93649167]     (1,)   aircraft:canard:characteristic_length
#     aircraft:canard:fineness                        [0.3]            (1,)   aircraft:canard:fineness
#     aircraft:fuselage:characteristic_length         [120.]           (1,)   aircraft:fuselage:characteristic_length
#     aircraft:fuselage:fineness                      [8.]             (1,)   aircraft:fuselage:fineness
#     aircraft:horizontal_tail:characteristic_length  [3.87298335]     (1,)   aircraft:horizontal_tail:characteristic_length
#     aircraft:horizontal_tail:fineness               [0.5]            (1,)   aircraft:horizontal_tail:fineness
#     aircraft:nacelle:characteristic_length          [23.]            (1,)   aircraft:nacelle:characteristic_length
#     aircraft:nacelle:fineness                       [1.91666667]     (1,)   aircraft:nacelle:fineness
#     aircraft:vertical_tail:characteristic_length    [0.]             (1,)   aircraft:vertical_tail:characteristic_length
#     aircraft:vertical_tail:fineness                 [0.]             (1,)   aircraft:vertical_tail:fineness
#     aircraft:wing:characteristic_length             [0.19775]        (1,)   aircraft:wing:characteristic_length
#     aircraft:wing:fineness                          [0.]             (1,)   aircraft:wing:fineness
#   total_wetted_area
#     aircraft:design:total_wetted_area               [4486.42849915]  (1,)   aircraft:design:total_wetted_area
#
#
# 0 Implicit Output(s) in 'model'
